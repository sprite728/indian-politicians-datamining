# %%
import glob
import re
from HTMLParser import HTMLParser

list_of_html_files = glob.glob('raw/*.html')
for file_index, file_name in enumerate(list_of_html_files):
    if file_index == 0: # For development, only get the first html file
        print str(file_index) + " " + file_name
        FI = open(file_name, 'r')
        content = FI.read()
        #m = re.search("<tr><td><strong>Name</strong></td><td>(?P=name)</td></tr>", content)
            # id="maincontent"
            # <tr><td><strong>Name</strong></td><td>Shri Kabir Suman</td></tr>
            # Father's Name
            # Mother's Name
            # Date of Birth, ex: 16 Mar 1950
            # ...
# Out:
# 0 raw/loksabhampbiodata0118.html

# %%
content

m = re.search("<tr><td><strong>Name</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
m.group(1)
# Out:
# 'Shri Kabir Suman'

# %%
# Out:
# '<tr><td><strong>Name</strong></td><td>Shri Kabir Suman</td></tr>'

# %%
import csv
FI_politicians = open("../priyank_politicians/politicians.csv", 'r')

# %%
reader = csv.reader(FI_politicians, delimiter=",")

for row in reader:
    print row

# %%
import csv
FI_politicians = open("../priyank_politicians/politicians.csv", 'r')

dict_reader = csv.DictReader(FI_politicians,  delimiter=",")
for row in dict_reader:
    print row['Name of elected M.P.']
    print row['Birthdate']
# Out:
# Ramesh Rathod
# 20/10/1966
# G. Vivekanand
# 30/11/1957
# Ponnam Prabhakar
# 05/08/1967
# Madhu Goud Yaskhi
# 15/12/1960
# Suresh Kumar Shetkar
# 08/08/1960
# Vijaya Shanthi M
# 24/6/1966
# Sarvey Sathyanarayana
# 04/04/1954
# M. Anjan Kumar Yadav
# 05/05/1961
# Asaduddin Owaisi
# 13/05/1969
# Jaipal Reddy Sudini
# 16/01/1942
# K. Chandrashekar Rao
# 17/02/1954
# Manda Jagannath
# 22/05/1951
# Gutha Sukender Reddy
# 02/02/1954
# Komatireddy Raj Gopal Reddy
# 06/01/1967
# Rajaiah Siricilla
# 09/05/1953
# Balram Porika Naik
# 06/06/1964
# Nama Nageswara Rao
# 15/03/1957
# Kishore Chandra Suryanarayana Deo Vyricherla
# 15/02/1947
# Killi Krupa Rani
# 19/11/1965
# Jhansi Lakshmi Botcha
# 04/11/1964
# Daggubati Purandeswari
# 22/04/1959
# Sabbam Hari
# 06/01/1952
# Mallipudi Raju Pallam Mangapati
# 31/08/1962
# G. V. Harsha Kumar
# 06/09/1959
# Aruna Kumar Vundavalli
# 08/04/1954
# Bapiraju Kanumuru
# 25/06/1947
# Kavuri Sambasiva Rao
# 10/02/1943
# Konakalla Narayana Rao
# 05/04/1950
# Rajagopal Lagadapati
# 16/02/1964
# Sambasiva Rayapati Rao
# 07/06/1943
# Modugula Venugopala Reddy
# 29/05/1966
# Lakshmi Panabaka
# 06/10/1958
# Magunta Sreenivasulu Reddy
# 15/10/1953
# S. P. Y. Reddy
# 06/04/1950
# Kotla Jayasurya Prakasha Reddy
# 18/09/1951
# Anantha Venkatarami Reddy
# #N/A
# Kristappa Nimmala
# #N/A
# Y. S. Jagan Mohan Reddy
# 21/12/1972
# Mekapati Rajamohan Reddy
# 06/11/1944
# Chinta Mohan
# #N/A
# Sai Prathap Annayyagari
# 20/09/1944
# 16/06/1958
# K. C. Singh Baba
# 29/03/1947
# Harish Rawat
# 27/04/1948
# Nripendra Nath Roy
# #N/A
# Manohar Tirkey
# 20/11/1953
# Mahendra Kumar Roy
# #N/A
# Jaswant Singh
# 01/03/1938
# Deepa Dasmunsi
# 15/07/1960
# Prasanta Kumar Majumdar
# #N/A
# Mausam Noor
# 15/10/1979
# Abu Hasem Khan Choudhury
# 01/12/1938
# Abhijit Mukherjee
# 01/02/1960
# Adhir Ranjan Chowdhury
# 04/02/1956
# Abdul Mannan Hossain
# #N/A
# Tapas Paul
# 08/02/1958
# Sucharu Ranjan Haldar
# #N/A
# Gobinda Chandra Naskar
# 16/06/1941
# Dinesh Trivedi
# #N/A
# Saugata Roy
# 08/06/1947
# Kakali Ghosh Dastidar
# 23/11/1959
# Haji Nurul Islam
# 11/11/1963
# Tarun Mondal
# #N/A
# Choudhury Mohan Jatua
# #N/A
# Somendra Nath Mitra
# #N/A
# Kabir Suman
# 16/03/1950
# Mamata Banerjee
# 23/07/1950
# Sudip Bandyopadhyay
# 12/10/1952
# Prasun Banerjee
# #N/A
# Sultan Ahmed
# 06/06/1953
# Kalyan Banerjee
# #N/A
# Ratna De (Nag)
# 09/06/1948
# Malik Sakti Mohan
# #N/A
# Suvendu Adhikari
# 15/12/1970
# Sisir Adhikari
# 19/09/1941
# Gurudas Dasgupta
# 11/03/1936
# Pulin Bihari Baske
# #N/A
# Prabodh Panda
# 02/07/1946
# Narahari Mahato
# 03/10/1956
# Acharia Basudeb
# 07/11/1942
# Susmita Bauri
# 01/05/1975
# Anup Kumar Saha
# 23/01/1956
# Sk. Saidul Haque
# #N/A
# Bansa Gopal Chowdhury
# #N/A
# Ram Chandra Dome
# 02/08/1959
# Satabdi Roy
# 10/05/1969
# Bishnu Pada Ray
# 19/06/1950
# Pawan Kumar Bansal
# 16/07/1948
# Patel Natubhai Gomanbhai
# #N/A
# Lalubhai Patel
# 31/08/1955
# Kapil Sibal
# 08/08/1948
# Jai Prakash Agarwal
# 11/11/1944
# Sandeep Dikshit
# 15/08/1964
# Ajay Makan
# #N/A
# Krishna Tirath
# 03/03/1955
# Mahabal Mishra
# 31/07/1953
# Ramesh Kumar
# 20/04/1955
# Muhammed Hamdulla Sayeed
# 04/11/1982
# V. Narayanasamy
# 30/05/1947

# %%
hello = dict()
hello['hi'] = {
    'value1': 'hi',
    'value2': 'yo'
    
}

# %%
hello
# Out:
# {'hi': {'value1': 'hi', 'value2': 'yo'}}

# %%
hello['hi']['value1']
# Out:
# 'hi'

# %%
politicians = {}

FI_politicians = open("../priyank_politicians/politicians.csv", 'r')

dict_reader = csv.DictReader(FI_politicians,  delimiter=",")
for row in dict_reader:
    
    name_in_politician = row['Name of elected M.P.']
    bday_in_politician = row['Birthdate']

    politicians[name_in_politician] = {
        'bday_in_politician': bday_in_politician
    }

# %%
politicians
# Out:
# {'A K S Vijayan': {'bday_in_politician': '15/12/1961'},
#  'A Raja': {'bday_in_politician': '#N/A'},
#  'A Sampath': {'bday_in_politician': '22/07/1962'},
tm_hour=0, tm_min=0, tm_sec=0, tm_wday=3, tm_yday=75, tm_isdst=-1)

# %%
bday_date.tm_year
# Out:
# 1950

# %%
bday_date.n_sequence_fields
# Out:
# 9

# %%
bday_2 = "25/12/1951"
bday_2_date = time.strptime(bday_2, "%d/%m/%Y")

# %%
bday_2_date
# Out:
# time.struct_time(tm_year=1951, tm_mon=12, tm_mday=25, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=359, tm_isdst=-1)

# %%
str(bday_2_date)
# Out:
# 'time.struct_time(tm_year=1951, tm_mon=12, tm_mday=25, tm_hour=0, tm_min=0, tm_sec=0, tm_wday=1, tm_yday=359, tm_isdst=-1)'

# %%
def convertHtmlBdayToStandard(bday_str):
    btime = time.strptime(bday_str, "%d %b %Y")
    return bdate.tm_day + "/" + bdate.tm_mon + "/" + bdate.tm_year

# %%
convertHtmlBdayToStandard("16 Mar 1950")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-56-6beb81f8dd26> in <module>()
# ----> 1 convertHtmlBdayToStandard("16 Mar 1950")
#
# <ipython-input-55-b5e5ddbbd4dc> in convertHtmlBdayToStandard(bday_str)
#       3 def convertHtmlBdayToStandard(bday_str):
#       4     btime = time.strptime(bday_str, "%d %b %Y")
# ----> 5     return bdate.tm_day + "/" + bdate.tm_mon + "/" + bdate.tm_year
#
# NameError: global name 'bdate' is not defined

# %%
def convertHtmlBdayToStandard(bday_str):
    btime = time.strptime(bday_str, "%d %b %Y")
    return btime.tm_mday + "/" + btime.tm_mon + "/" + btime.tm_year

# %%
convertHtmlBdayToStandard("16 Mar 1950")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-6beb81f8dd26> in <module>()
# ----> 1 convertHtmlBdayToStandard("16 Mar 1950")
#
# <ipython-input-59-88a082ba328c> in convertHtmlBdayToStandard(bday_str)
#       2 def convertHtmlBdayToStandard(bday_str):
#       3     btime = time.strptime(bday_str, "%d %b %Y")
# ----> 4     return btime.tm_mday + "/" + btime.tm_mon + "/" + btime.tm_year
#       5
#       6
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
i = 10
test = "%s, %s" % ( i, i)
print test
# Out:
# 10, 10

# %%
def convertHtmlBdayToStandard(bday_str):
    btime = time.strptime(bday_str, "%d %b %Y")
    return "%s/%s/%s" % (btime.tm_mday, btime.tm_mon, btime.tm_year)

convertHtmlBdayToStandard("16 Mar 1950")
# Out:
# '16/3/1950'

# %%
import ipdb

politicians_from_html = {}

list_of_html_files = glob.glob('raw/*.html')
for file_index, file_name in enumerate(list_of_html_files):
    print str(file_index) + " " + file_name
    FI = open(file_name, 'r')
    content = FI.read()

    m = re.search("<tr><td><strong>Name</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    name_in_html = m.group(1)

    m = re.search("<tr><td><strong>Date of Birth</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    bday_in_html = m.group(1) #format: "16 Mar 1950"
    
    ipdb.set_trace()
    bday_in_html = convertHtmlBdayToStandard(bday_in_html)

    politicians_from_html[name_in_html] = {
        'bday_in_html': bday_in_html
    }
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-67-2a4d09beda1b> in <module>()
#      16
#      17     ipdb.set_trace()
# ---> 18     bday_in_html = convertHtmlBdayToStandard(bday_in_html)
#      19
#      20     politicians_from_html[name_in_html] = {
#
# <ipython-input-67-2a4d09beda1b> in <module>()
#      16
#      17     ipdb.set_trace()
# ---> 18     bday_in_html = convertHtmlBdayToStandard(bday_in_html)
#      19
#      20     politicians_from_html[name_in_html] = {
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.pyc in dispatch_line(self, frame)
#      64     def dispatch_line(self, frame):
#      65         if self.stop_here(frame) or self.break_here(frame):
# ---> 66             self.user_line(frame)
#      67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pdb.pyc in user_line(self, frame)
#     156             self._wait_for_mainpyfile = 0
#     157         if self.bp_commands(frame):
# --> 158             self.interaction(frame, None)
#     159
#     160     def bp_commands(self,frame):
#
# /Library/Python/2.7/site-packages/ipython-0.13-py2.7.egg/IPython/core/debugger.pyc in interaction(self, frame, traceback)
#     249     def interaction(self, frame, traceback):
#     250         self.shell.set_completer_frame(frame)
# --> 251         OldPdb.interaction(self, frame, traceback)
#     252
#     253     def new_do_up(self, arg):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pdb.pyc in interaction(self, frame, traceback)
#     208         self.setup(frame, traceback)
#     209         self.print_stack_entry(self.stack[self.curindex])
# --> 210         self.cmdloop()
#     211         self.forget()
#     212
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/cmd.pyc in cmdloop(self, intro)
#     128                     if self.use_rawinput:
#     129                         try:
# --> 130                             line = raw_input(self.prompt)
#     131                         except EOFError:
#     132                             line = 'EOF'
#
# /Library/Python/2.7/site-packages/ipython-0.13-py2.7.egg/IPython/zmq/ipkernel.pyc in <lambda>(prompt)
#     343             raw_input = lambda prompt='': self._raw_input(prompt, ident, parent)
#     344         else:
# --> 345             raw_input = lambda prompt='' : self._no_raw_input()
#     346
#     347         if py3compat.PY3:
#
# /Library/Python/2.7/site-packages/ipython-0.13-py2.7.egg/IPython/zmq/ipkernel.pyc in _no_raw_input(self)
#     686         """Raise StdinNotImplentedError if active frontend doesn't support
#     687         stdin."""
# --> 688         raise StdinNotImplementedError("raw_input was called, but this "
#     689                                        "frontend does not support stdin.")
#     690
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support stdin.

# %%
list_of_html_files = glob.glob('raw/*.html')
for file_index, file_name in enumerate(list_of_html_files):
    print str(file_index) + " " + file_name
    FI = open(file_name, 'r')
    content = FI.read()

    m = re.search("<tr><td><strong>Name</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    name_in_html = m.group(1)

    m = re.search("<tr><td><strong>Date of Birth</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    bday_in_html = m.group(1) #format: "16 Mar 1950"
    print bday_in_html

# %%
list_of_html_files = glob.glob('raw/*.html')
for file_index, file_name in enumerate(list_of_html_files):
    print str(file_index) + " " + file_name
    FI = open(file_name, 'r')
    content = FI.read()

    m = re.search("<tr><td><strong>Name</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    name_in_html = m.group(1)
    print name_in_html

    m = re.search("<tr><td><strong>Date of Birth</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    bday_in_html = m.group(1) #format: "16 Mar 1950"
    print bday_in_html

# %%
politicians_from_html = {}

list_of_html_files = glob.glob('raw/*.html')
for file_index, file_name in enumerate(list_of_html_files):
    print str(file_index) + " " + file_name
    FI = open(file_name, 'r')
    content = FI.read()

    m = re.search("<tr><td><strong>Name</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    name_in_html = m.group(1)
    print name_in_html

    m = re.search("<tr><td><strong>Date of Birth</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    bday_in_html = m.group(1) #format: "16 Mar 1950"
    print bday_in_html

    if bday_in_html == "-NA-"
        bday_in_html = "NA"
    else:
        bday_in_html = convertHtmlBdayToStandard(bday_in_html)

    # politicians_from_html[name_in_html] = {
    #     'bday_in_html': bday_in_html
    # }

# %%
politicians_from_html

# %%
list_of_html_files = glob.glob('raw/*.html')
for file_index, file_name in enumerate(list_of_html_files):
    print str(file_index) + " " + file_name
    FI = open(file_name, 'r')
    content = FI.read()

    m = re.search("<tr><td><strong>Name</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    name_in_html = m.group(1)
    print name_in_html

    m = re.search("<tr><td><strong>Date of Birth</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    bday_in_html = m.group(1) #format: "16 Mar 1950"
    print bday_in_html

    if bday_in_html == "-NA-"
        bday_in_html = "NA"
    else:
        bday_in_html = convertHtmlBdayToStandard(bday_in_html)

    politicians_from_html[name_in_html] = {
        'bday_in_html': bday_in_html
    }

# %%
politicians_from_html

# %%
from pymongo import MongoClient

client = MongoClient("dhcp3-234.si.umich.edu", 27017)
db = client.india
raw_politicians = db.raw_politicians
raw_politicians_from_html = db.raw_politicians_from_html

# %%
"""
	lowerhouse_gov_website parser
	author: Chuan-Che Jeff Huang
	email: chuanche@umich.edu

	Description
	1. Read Html files in raw/
	2. Compare the names in the html files with Politicians.xlsx
	3. Generate an intermediate name mapping files
	4. We, researchers, confirm in the name mappings are correct
	5. Delegate the later data combining task to another parser

	Note
	- Criteria
		User should be able to easily re-run this program when a field in 
		the Politicians.xlsx or HTML files are updated. 


"""

import glob
import re, csv
import time
import ipdb

from HTMLParser import HTMLParser

from pymongo import MongoClient

HOST = "dhcp3-234.si.umich.edu"
PORT = 27017

"""
Name mapping data structure

name_in_politicians, name_in_html, 

Process
    1. Put all the names and birthday from name_in_politicians into a dictionary
        "Politicians"
        - key: politician name
        - value: 
            -key: source
                - value: "politicians" or "html" 
            -key: name_in_politicians
            -key: name_in_html
            -key: bday_in_politicians
            -key: bday_in_html
            -key: problem

       
    2. Get a politician name and birthday from html file
    3. See if this politician matches any of the name in the 
        "Politicians", 
        if yes:
            - check to see if bday is matched 
            if yes:
                - set bday_in_html, name_in_html
            if not:
                - set bday_in_html, name_in_html
                - set problem = True
        if not:
            - create a new item in dictionary
                - key: name_in_html
                - value
                    -key: source = "html"

            - set bday_in_html
            - set 'problem' to True


    4. Output to a csv file

"""
politicians = {}

FI_politicians = open("../priyank_politicians/politicians.csv", 'r')

dict_reader = csv.DictReader(FI_politicians,  delimiter=",")
for row in dict_reader:
    
    name_in_politician = row['Name of elected M.P.']
    bday_in_politician = row['Birthdate'] #format: 25/12/1951

    politicians[name_in_politician] = {
        'bday_in_politician': bday_in_politician
    }


politicians_from_html = {}

list_of_html_files = glob.glob('raw/*.html')
for file_index, file_name in enumerate(list_of_html_files):
    print str(file_index) + " " + file_name
    FI = open(file_name, 'r')
    content = FI.read()

    m = re.search("<tr><td><strong>Name</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    name_in_html = m.group(1)
    print name_in_html

    m = re.search("<tr><td><strong>Date of Birth</strong></td><td>(.*?)</td></tr>", content, re.I|re.DOTALL)
    bday_in_html = m.group(1) #format: "16 Mar 1950"
    bday_in_html = bday_in_html.strip('\n\t')

    if bday_in_html == "-NA-":
        bday_in_html = "NA"
    else:
        print bday_in_html
        try:
            bday_in_html = convertHtmlBdayToStandard(bday_in_html)
        except:
            #ipdb.set_trace()
            pass
        
    politicians_from_html[name_in_html] = {
        'bday_in_html': bday_in_html
    }


def convertHtmlBdayToStandard(bday_str):
    btime = time.strptime(bday_str, "%d %b %Y")
    return "%s/%s/%s" % (btime.tm_mday, btime.tm_mon, btime.tm_year)
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-1-a187b52d01c9> in <module>()
#     113             ipdb.set_trace()
#     114
# --> 115     politicians_from_html[name_in_html] = {
#     116         'bday_in_html': bday_in_html
#     117     }
#
# <ipython-input-1-a187b52d01c9> in <module>()
#     113             ipdb.set_trace()
#     114
# --> 115     politicians_from_html[name_in_html] = {
#     116         'bday_in_html': bday_in_html
#     117     }
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.pyc in dispatch_line(self, frame)
#      64     def dispatch_line(self, frame):
#      65         if self.stop_here(frame) or self.break_here(frame):
# ---> 66             self.user_line(frame)
#      67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pdb.pyc in user_line(self, frame)
#     156             self._wait_for_mainpyfile = 0
#     157         if self.bp_commands(frame):
# --> 158             self.interaction(frame, None)
#     159
#     160     def bp_commands(self,frame):
#
# /Library/Python/2.7/site-packages/ipython-0.13-py2.7.egg/IPython/core/debugger.pyc in interaction(self, frame, traceback)
#     249     def interaction(self, frame, traceback):
#     250         self.shell.set_completer_frame(frame)
# --> 251         OldPdb.interaction(self, frame, traceback)
#     252
#     253     def new_do_up(self, arg):
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pdb.pyc in interaction(self, frame, traceback)
#     208         self.setup(frame, traceback)
#     209         self.print_stack_entry(self.stack[self.curindex])
# --> 210         self.cmdloop()
#     211         self.forget()
#     212
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/cmd.pyc in cmdloop(self, intro)
#     128                     if self.use_rawinput:
#     129                         try:
# --> 130                             line = raw_input(self.prompt)
#     131                         except EOFError:
#     132                             line = 'EOF'
#
# /Library/Python/2.7/site-packages/ipython-0.13-py2.7.egg/IPython/zmq/ipkernel.pyc in <lambda>(prompt)
#     343             raw_input = lambda prompt='': self._raw_input(prompt, ident, parent)
#     344         else:
# --> 345             raw_input = lambda prompt='' : self._no_raw_input()
#     346
#     347         if py3compat.PY3:
#
# /Library/Python/2.7/site-packages/ipython-0.13-py2.7.egg/IPython/zmq/ipkernel.pyc in _no_raw_input(self)
#     686         """Raise StdinNotImplentedError if active frontend doesn't support
#     687         stdin."""
# --> 688         raise StdinNotImplementedError("raw_input was called, but this "
#     689                                        "frontend does not support stdin.")
#     690
#
# StdinNotImplementedError: raw_input was called, but this frontend does not support stdin.

# %%
politicians
